# %% [markdown]
# # If you happy and I know it you can enter my House
#
# You'll see how you can in a couple of hours build a deep learning algorithm.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %% [markdown]
# This dataset can be used to solve the Happy House problem.
# Where, we allow a person to enter the house only if he/she is smiling!
# So, a smile detector!

# %% [markdown]
# ![Texte alternatif…](https://raw.githubusercontent.com/Kulbear/deep-learning-coursera/master/Convolutional%20Neural%20Networks/images/house-members.png)

# %% [markdown]
# Details of the "Happy" dataset:
#
# * Images are of shape (64,64,3)
# * Training: 600 pictures
# * Test: 150 pictures

# %% [markdown]
# # Load Dataset

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test =  Y_test_orig.T


print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[10])
# Out:
# Image shape : (64, 64, 3)

# %% [markdown]
# # Building Model

# %% [markdown]
# _________________________________________________________________
#
# conv2d_3 (Conv2D)            (None, 64, 64, 32)        4736
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 64, 64, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 32769
# _________________________________________________________________

# %%
model = Sequential()
model.add(Conv2D(32, (7, 7),padding = 'same',activation = 'relu' ,input_shape = (64,64,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2,2),strides =2))

model.add(Flatten())
#model.add(Dense(64,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=["accuracy"])

# %%
history_model = model.fit(X_train, Y_train, epochs=40, batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/40
# 15/15 [==============================] - 4s 227ms/step - loss: 1.0074 - accuracy: 0.6687 - val_loss: 0.5776 - val_accuracy: 0.7667
# Epoch 2/40
# 15/15 [==============================] - 3s 216ms/step - loss: 0.2837 - accuracy: 0.8875 - val_loss: 0.5303 - val_accuracy: 0.9417
# Epoch 3/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.2327 - accuracy: 0.9021 - val_loss: 0.4895 - val_accuracy: 0.8917
# Epoch 4/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.1314 - accuracy: 0.9563 - val_loss: 0.5220 - val_accuracy: 0.7750
# Epoch 5/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0936 - accuracy: 0.9729 - val_loss: 0.4698 - val_accuracy: 0.9000
# Epoch 6/40
# 15/15 [==============================] - 3s 218ms/step - loss: 0.0959 - accuracy: 0.9708 - val_loss: 0.4250 - val_accuracy: 0.9667
# Epoch 7/40
# 15/15 [==============================] - 3s 219ms/step - loss: 0.0620 - accuracy: 0.9854 - val_loss: 0.4192 - val_accuracy: 0.9500
# Epoch 8/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.1150 - accuracy: 0.9604 - val_loss: 0.4185 - val_accuracy: 0.9583
# Epoch 9/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0904 - accuracy: 0.9792 - val_loss: 0.3825 - val_accuracy: 0.9417
# Epoch 10/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.1091 - accuracy: 0.9625 - val_loss: 0.4517 - val_accuracy: 0.8417
# Epoch 11/40
# 15/15 [==============================] - 3s 218ms/step - loss: 0.0834 - accuracy: 0.9750 - val_loss: 0.3378 - val_accuracy: 0.9500
# Epoch 12/40
# 15/15 [==============================] - 3s 216ms/step - loss: 0.0767 - accuracy: 0.9792 - val_loss: 0.5163 - val_accuracy: 0.6083
# Epoch 13/40
# 15/15 [==============================] - 3s 218ms/step - loss: 0.0584 - accuracy: 0.9771 - val_loss: 0.4200 - val_accuracy: 0.8500
# Epoch 14/40
# 15/15 [==============================] - 3s 214ms/step - loss: 0.0478 - accuracy: 0.9854 - val_loss: 0.3274 - val_accuracy: 0.9583
# Epoch 15/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0323 - accuracy: 0.9896 - val_loss: 0.2464 - val_accuracy: 0.9833
# Epoch 16/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0378 - accuracy: 0.9854 - val_loss: 0.2935 - val_accuracy: 0.9083
# Epoch 17/40
# 15/15 [==============================] - 3s 214ms/step - loss: 0.0384 - accuracy: 0.9854 - val_loss: 0.2377 - val_accuracy: 0.9917
# Epoch 18/40
# 15/15 [==============================] - 3s 216ms/step - loss: 0.0277 - accuracy: 0.9917 - val_loss: 0.2415 - val_accuracy: 0.9917
# Epoch 19/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0302 - accuracy: 0.9875 - val_loss: 0.2350 - val_accuracy: 0.9417
# Epoch 20/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0232 - accuracy: 0.9958 - val_loss: 0.1872 - val_accuracy: 0.9750
# Epoch 21/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0270 - accuracy: 0.9917 - val_loss: 0.1753 - val_accuracy: 0.9833
# Epoch 22/40
# 15/15 [==============================] - 3s 216ms/step - loss: 0.0243 - accuracy: 0.9937 - val_loss: 0.1543 - val_accuracy: 0.9917
# Epoch 23/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0181 - accuracy: 0.9958 - val_loss: 0.1353 - val_accuracy: 0.9833
# Epoch 24/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.1549 - val_accuracy: 0.9417
# Epoch 25/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.1760 - val_accuracy: 0.9167
# Epoch 26/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0239 - accuracy: 0.9979 - val_loss: 0.1753 - val_accuracy: 0.9167
# Epoch 27/40
# 15/15 [==============================] - 3s 216ms/step - loss: 0.0175 - accuracy: 0.9958 - val_loss: 0.1348 - val_accuracy: 0.9500
# Epoch 28/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.1392 - val_accuracy: 0.9500
# Epoch 29/40
# 15/15 [==============================] - 3s 216ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.1007 - val_accuracy: 0.9833
# Epoch 30/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0854 - val_accuracy: 0.9833
# Epoch 31/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0126 - accuracy: 0.9979 - val_loss: 0.0663 - val_accuracy: 0.9917
# Epoch 32/40
# 15/15 [==============================] - 3s 218ms/step - loss: 0.0098 - accuracy: 0.9958 - val_loss: 0.0570 - val_accuracy: 0.9917
# Epoch 33/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0903 - val_accuracy: 0.9750
# Epoch 34/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.2088 - val_accuracy: 0.9083
# Epoch 35/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0765 - val_accuracy: 0.9750
# Epoch 36/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0185 - accuracy: 0.9958 - val_loss: 0.0826 - val_accuracy: 0.9750
# Epoch 37/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0117 - accuracy: 0.9979 - val_loss: 0.0561 - val_accuracy: 0.9833
# Epoch 38/40
# 15/15 [==============================] - 3s 215ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0461 - val_accuracy: 0.9833
# Epoch 39/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0114 - accuracy: 0.9958 - val_loss: 0.0451 - val_accuracy: 0.9833
# Epoch 40/40
# 15/15 [==============================] - 3s 217ms/step - loss: 0.0182 - accuracy: 0.9937 - val_loss: 0.2355 - val_accuracy: 0.9167

# %% [markdown]
# # Evaluate / Test

# %%
train_accuracy = history_model.history['accuracy']
train_loss = history_model.history['loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %% [markdown]
# Evaluate Test set

# %%
model.evaluate(X_test, Y_test)
# Out:
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2450 - accuracy: 0.9000
# [0.2450394183397293, 0.8999999761581421]

# %%
 y_pred = model.predict(X_test)

# %% [markdown]
# Confusion Matrix

# %%
#from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred>0.5)
sns.heatmap(cm,annot = True)

# %% [markdown]
# # Note
#
# Before you submit your work
#
# * You should compare different optimizers
#
# ---
#
# * Display images with Predicted & expected labels (Happy-sad)

# %%
class_name = ['sad','happy']
plt.figure(figsize=(30,30))
for i in range(64):
  ax = plt.subplot(8 ,8 ,i+1)
  plt.imshow(X_test[i])
  if y_pred[i]>=0.5:
    
    plt.title("happy /"+class_name[Y_test[i][0]])
  if y_pred[i]<0.5:
    plt.title("sad /"+class_name[Y_test[i][0]])
    plt.axis('off')
